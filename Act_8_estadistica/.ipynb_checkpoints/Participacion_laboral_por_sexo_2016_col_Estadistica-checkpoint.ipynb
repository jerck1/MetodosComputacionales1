# %% [markdown]
# # <center> Datos sobre la oferta laboral del ministerio de trabajo <center>
# En el archivo adjunto encontrarán información sobre la participación laboral en el año 2016, para familias que pueden ingresar al ministerio.
#
#
# Escoja una muestra aleatoria de n=50 datos. +5
#
# Realice una tabla de frecuencias sobre las variables.+20
#
# Estime el salario promedio de las esposas y de los esposos.+5
#
# Realice un histograma sobre las variables edad del esposo.+10
#
# Estime la probabilidad de que la edad promedio de la esposa participe en el mercado laboral. Para esto encuentre el intervalo y la frecuencia correspondiente a la edad promedio.+5
#
# Estime la probabilidad de que la edad promedio de la esposa no participe en el mercado laboral+5
#
# Envíenme un notebook con los resultados.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import sample

# %%
info=pd.read_csv("informacion.txt",delimiter="\t")

# %%
info
# Out:
#       Variable name    Storage type                         Display format  \
# 0              inlf   byte    %9.0g  =1 si participa en el mercado laboral
# 1     horas_esposa   int     %9.0g                         horas laboradas
# 2             hijos   byte    %9.0g
# 3       edad_esposa   byte    %9.0g                           edad en años
# 4       educ_esposa   byte    %9.0g                         años educacion
# 5      horas_esposo   int     %9.0g          horas laboradas por el esposo
# 6       edad_esposo   byte    %9.0g                años de edad del esposo
# 7       educ_esposo   byte    %9.0g                  años educacion esposo
# 8           ingreso   float   %9.0g
# 9      exper_esposa   byte    %9.0g            experiencia laboral en años
# 10          d_hijo6   float   %9.0g
# 11   salario_esposa           float                                  %9.0g
# 12   salario_esposo           float                                  %9.0g
# ...

# %%
datos=pd.read_csv("trabajo.txt",delimiter="\t")

# %%
datos
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 0       1          1610      1           32           12          2708
# 1       1          1656      0           30           12          2310
# 2       1          1980      1           35           12          3072
# 3       1           456      0           34           12          1920
# 4       1          1568      1           31           14          2000
# ..    ...           ...    ...          ...          ...           ...
# 748     0             0      0           40           13          3020
# 749     0             0      2           31           12          2056
# 750     0             0      0           43           12          2383
# 751     0             0      0           60           12          1705
# 752     0             0      0           39            9          3120
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# ...

# %%
indices=sample(list(datos.index),50)

# %%
for i in indices:
    for x in datos["inlf"]:
        if(i)
# Out:
# 1

# %%
datos["inlf"][indices]
# Out:
# 352    1
# 200    1
# 473    0
# 121    1
# 303    1
# 81     1
# 486    0
# 408    1
# 20     1
# 442    0
# 274    1
# 557    0
# 209    1
# 299    1
# 649    0
# 426    1
# 247    1
# 601    0
# 643    0
# 177    1
# 361    1
# 2      1
# 735    0
# 598    0
# 266    1
# 52     1
# 152    1
# 498    0
# 263    1
# 527    0
# 174    1
# 626    0
# 745    0
# 489    0
# 323    1
# 12     1
# 740    0
# 750    0
# 231    1
# 53     1
# 163    1
# 607    0
# 210    1
# 360    1
# 221    1
# 197    1
# 374    1
# 87     1
# 570    0
# 148    1
# Name: inlf, dtype: int64

# %%
plt.figure()
plt.hist(datos["inlf"][indices],bins=2)#,density=True)
plt.show()

# %%
columnas=datos.columns
#Mi código
cnt0=0;cnt1=0;
for col in columnas:
    for x in datos[col][indices]:
        if x==0:
            cnt0+=1
        else:
            cnt1+=1

# %%
# Out:
# 30 20

# %%
# Out:
# 'inlf'

# %%
datos.values[0]
# Out:
# array([1.000000e+00, 1.610000e+03, 1.000000e+00, 3.200000e+01,
#        1.200000e+01, 2.708000e+03, 3.400000e+01, 1.200000e+01,
#        8.155000e+05, 1.400000e+01, 1.000000e+00, 1.274520e+04,
#        1.530944e+04, 1.000000e+00, 3.000000e+00])
