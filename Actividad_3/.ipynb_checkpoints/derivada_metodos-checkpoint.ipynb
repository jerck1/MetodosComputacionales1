# %% [markdown]
# # <center> Métodos para calcular la derivada numérica <center>

# %% [markdown]
# ## Derivada hacia adelante: (Error de h^2)
# $$f'(x)\simeq \frac{f(x+h)-f(x)}{h}$$
# ## Derivada hacia atrás:
# $$f'(x)\simeq \frac{f(x)-f(x-h)}{h}$$
# ## Derivada con diferencia central: (resto h^3)
# $$f'(x)\simeq \frac{f(x+h)-f(x-h)}{2h}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x,n,A1=1e-6,A2=1e-6,A=1):#n: nos permitirá movernos entre una función y otra
    if(n==1):
        return A1/x**6-A2/x**12
    elif(n==2):
        return A*np.cos(x)

# %%
x=np.pi
n=2
f(x,n)
# Out:
# -1.0

# %%
def derivada_adelante(x,n,h):
    return (f(x+h,n)-f(x,n))/h

# %%
x=np.linspace(0.0001,10,100)# 100 puntos entre 0.01 y 10
n=2# primero 0.1, luego 0.05, 1 , 1e-3,1-e4
h=0.1
print("Función")
print(f(x,n))
df=derivada_adelante(x,n,h)
print("Derivada")
print(np.shape(df))
# Out:
# Función
# [ 1.          0.99489283  0.97964356  0.95440765  0.91944234  0.87510409
#   0.82184489  0.76020766  0.69082075  0.6143915   0.53169904  0.44358636
#   0.35095168  0.25473934  0.15593015  0.05553138 -0.04543348 -0.14593519
#  -0.24494921 -0.34146618 -0.43450219 -0.52310881 -0.60638277 -0.68347517
#  -0.75360011 -0.81604272 -0.87016646 -0.91541958 -0.95134077 -0.97756382
#  -0.99382144 -0.99994787 -0.99588067 -0.9816613  -0.95743471 -0.92344787
#  -0.88004726 -0.8276753  -0.76686588 -0.6982389  -0.62249396 -0.54040322
#  -0.45280351 -0.36058785 -0.2646963  -0.1661064  -0.06582317  0.03513106
#   0.13572717  0.23493964  0.33175711  0.42519259  0.51429358  0.59815179
#   0.67591233  0.74678251  0.81003987  0.86503955  0.91122088  0.94811306
#   0.97534003  0.99262422  0.99978944  0.99676264  0.98357467  0.96035999
#   0.92735523  0.88489686  0.83341771  0.77344257  0.70558282  0.63053024
#   0.54904994  0.46197253  0.37018569  0.27462512  0.17626498  0.07610797
#  -0.02482491 -0.12550471 -0.2249051  -0.32201277 -0.41583779 -0.50542368
#  -0.58985721 -0.66827764 -0.73988553 -0.80395091 -0.85982068 -0.90692529
#  -0.94478457 -0.97301255 -0.99132148 -0.99952472 -0.99753863 -0.98538348
#  -0.96318316 -0.931164   -0.8896524  -0.83907153]
# Derivada
# (100,)

# %%
plt.figure()
plt.plot(x,f(x,n),label="Acos(x)")
plt.plot(x,df,label="derivada_numerica")
plt.savefig("derivada_2da_funcion_adelante.png")
